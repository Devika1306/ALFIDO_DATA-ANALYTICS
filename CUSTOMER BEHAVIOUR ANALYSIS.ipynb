# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\hp\Downloads\customer_data.csv.zip")

# %%
df.head(2)
# Out:
#    id  age gender  income education region loyalty_status purchase_frequency  \
# 0   1   27   Male   40682  Bachelor   East           Gold           frequent
# 1   2   29   Male   15317   Masters   West        Regular               rare
#
#    purchase_amount product_category  promotion_usage  satisfaction_score
# 0            18249            Books                0                   6
# 1             4557         Clothing                1                   6

# %%
df.tail(2)
# Out:
#            id  age  gender  income education region loyalty_status  \
# 99998   99999   31  Female   40093  Bachelor   West        Regular
# 99999  100000   35  Female   22249   College   West         Silver
#
#       purchase_frequency  purchase_amount product_category  promotion_usage  \
# 99998           frequent            16312           Health                1
# 99999               rare             9426           Health                0
#
#        satisfaction_score
# 99998                   5
# 99999                   6

# %%
df.shape
# Out:
# (100000, 12)

# %%
df.dtypes
# Out:
# id                     int64
# age                    int64
# gender                object
# income                 int64
# education             object
# region                object
# loyalty_status        object
# purchase_frequency    object
# purchase_amount        int64
# product_category      object
# promotion_usage        int64
# satisfaction_score     int64
# dtype: object

# %%
df.isna().sum()
# Out:
# id                    0
# age                   0
# gender                0
# income                0
# education             0
# region                0
# loyalty_status        0
# purchase_frequency    0
# purchase_amount       0
# product_category      0
# promotion_usage       0
# satisfaction_score    0
# dtype: int64

# %%
df.nunique()
# Out:
# id                    100000
# age                       38
# gender                     2
# income                 40003
# education                  4
# region                     4
# loyalty_status             3
# purchase_frequency         3
# purchase_amount        18902
# product_category           7
# promotion_usage            2
# satisfaction_score        11
# dtype: int64

# %%
df.drop(columns='promotion_usage',inplace=True)

# %%
df.drop(columns='id',inplace=True)

# %%
df.sample(5)
# Out:
#        age  gender  income   education region loyalty_status  \
# 32300   30  Female   11394  HighSchool  South        Regular
# 84056   24  Female   23106  HighSchool   East        Regular
# 18884   33    Male   32343    Bachelor  North        Regular
# 59573   25    Male   26641    Bachelor   West         Silver
# 9329    31  Female   36986     College   East         Silver
#
#       purchase_frequency  purchase_amount product_category  satisfaction_score
# 32300         occasional             4652      Electronics                   4
# 84056         occasional             8711            Books                   8
# 18884         occasional            13766             Home                   5
# 59573               rare             8284         Clothing                   5
# 9329            frequent            13307      Electronics                   5

# %%
gender=df['gender'].value_counts()
gender
# Out:
# gender
# Female    50074
# Male      49926
# Name: count, dtype: int64

# %%
education=df['education'].value_counts()
education
# Out:
# education
# College       39874
# Bachelor      30279
# HighSchool    20031
# Masters        9816
# Name: count, dtype: int64

# %%
education = [25, 35, 20, 20]
plt.figure(figsize=(8, 6))
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99']
explode = (0, 0, 0, 0.1)
plt.pie(education, autopct='%1.0f%%', labels=['College', 'Bachelor', 'High School', 'Masters'], explode=explode, colors=colors, shadow=True, startangle=140)
plt.title('Distribution of Education', fontsize=16)
plt.axis('equal')
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")

sns.set_style("whitegrid")
plt.figure(figsize=(8, 6))

colors = ['#ff9999', '#66b3ff']
ax = sns.countplot(x='gender', data=df, palette=colors)
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.title('Distribution of Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
x = df['education'].value_counts()
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
explode = (0.1, 0, 0, 0)
plt.figure(figsize=(8, 6))
plt.pie(x.values, 
        labels=x.index, 
        autopct='%1.2f%%', 
        colors=colors,
        explode=explode,
        shadow=True,
        startangle=140)
plt.title('Distribution of Education Levels')
plt.axis('equal')
plt.show()

# %%
#The chart suggests that College education makes up the biggest share, at roughly 39%, while Masters education comprises the smallest, at about 9%.

# %%
df['region'].value_counts()
# Out:
# region
# East     30074
# West     29935
# South    20073
# North    19918
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
ax = sns.countplot(x='region', data=df, palette='Set2')
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0, 10), 
                textcoords = 'offset points')


plt.title('Distribution of Regions')
plt.xlabel('Region')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
df['loyalty_status'] = df['loyalty_status'].astype(str).replace('\.0', '', regex=True)

plt.figure(figsize=(10, 6))
ax = sns.countplot(x='loyalty_status', data=df, palette='pastel')
for p in ax.patches:
    ax.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=12, color='black', xytext=(0, 5),
                textcoords='offset points')

ax.set_xlabel('Loyalty Status', fontsize=14)
ax.set_ylabel('Count', fontsize=14)
ax.set_title('Count of Customers by Loyalty Status', fontsize=16)

plt.tight_layout()
plt.show()

# %%
df.describe()
# Out:
#                  age         income  purchase_amount  satisfaction_score
# count  100000.000000  100000.000000    100000.000000       100000.000000
# mean       30.003260   27516.269880      9634.790840            5.009650
# std         4.480535   12996.782587      4799.339449            1.038714
# min        12.000000    5000.000000      1118.000000            0.000000
# 25%        27.000000   16271.750000      5583.000000            4.000000
# 50%        30.000000   27584.500000      9452.000000            5.000000
# 75%        33.000000   38747.250000     13350.000000            6.000000
# max        49.000000   50000.000000     26204.000000           10.000000

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 8))
sns.histplot(df['age'], kde=True, color='skyblue')
plt.title('Histogram of Age', fontsize=16, fontweight='bold')
plt.xlabel('Age', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
sns.set_style("whitegrid")
sns.set_palette("husl")
sns.set_context("paper", font_scale=1.2)
plt.figure(figsize=(10, 8))
sns.lineplot(x='age', y='income', data=df, linewidth=2)
plt.title('Line Plot of Age vs. Income', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Income', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()
